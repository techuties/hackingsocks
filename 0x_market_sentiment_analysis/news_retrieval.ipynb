# %%
from datetime import datetime, timedelta

# %%
import requests

# %%
import yfinance as yf

# %%
def fetch_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data

# %%
import requests
from datetime import datetime
from typing import List

NEWSAPI_KEY = "396e086df39c4af4bbe13ce1c8dae26c"

def get_articles(stock_name: str, start_date: str, end_date: str) -> List[dict]:
    """
    Fetch news articles from NewsAPI for a given stock/company name
    between start_date and end_date (YYYY-MM-DD).
    """
    url = "https://newsapi.org/v2/everything"
    params = {
        "q": stock_name,
        "from": start_date,
        "to": end_date,
        "language": "en",
        "sortBy": "relevancy",
        "pageSize": 50,
        "apiKey": NEWSAPI_KEY
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json()
    return data.get("articles", [])

# Example usage:

# %%
def main():
    API_KEY = '5bc49699b6f34d80ae31553acc237aa3'
    query = "ICICI"
    start_date = '2024-09-20'
    end_date = '2024-10-18'

    # Fetching sentiment data
    daily_sentiment = {}
    current_date = datetime.strptime(start_date, '%Y-%m-%d')
    while current_date <= datetime.strptime(end_date, '%Y-%m-%d'):
        date_str = current_date.strftime('%Y-%m-%d')
        articles = fetch_news(API_KEY, query, date_str)
        daily_sentiment[date_str] = sentiment_final_date(articles)
        current_date += timedelta(days=1)

# Example usage:
# main()

# %%
stocks = {
 'MMM',      # 3M
 'ATVI',     # Activision Blizzard
 'ADBE',     # Adobe
 'AES',      # AES Corporation
 'AMZN',     # Amazon.com
 'AMCR',     # Amcor plc
 'AMD',      # Advanced Micro Devices
 'AXP',      # American Express Company
 'AWK',      # American Water Works Company
 'AAPL',     # Apple Inc.
 'BBY',      # Best Buy Co., Inc.
 'SQ',       # Block, Inc. (formerly Square)
 'BA',       # Boeing
 'BXP',      # Boston Properties, Inc.
 'KO',       # Coca-Cola Company
 'GLW',      # Corning Inc.
 'COST',     # Costco Wholesale Corporation
 'CVS',      # CVS Health Corporation
 'EBAY',     # eBay Inc.
 'FDX',      # FedEx Corporation
 'FL',       # Foot Locker, Inc.
 'GIS',      # General Mills, Inc.
 'INTC',     # Intel Corporation
 'JNJ',      # Johnson & Johnson
 'JPM',      # JPMorgan Chase & Co.
 'KHC',      # Kraft Heinz Company
 'LMT',      # Lockheed Martin Corporation
 'MCD',      # McDonald’s Corporation
 'MGM',      # MGM Resorts International
 'MSFT',     # Microsoft Corporation
 'NFLX',     # Netflix, Inc.
 'NKE',      # Nike, Inc.
 'ORCL',     # Oracle Corporation
 'PYPL',     # PayPal Holdings, Inc.
 'PEP',      # PepsiCo, Inc.
 'PFE',      # Pfizer Inc.
 'PG',       # Procter & Gamble Co.
 'CRM',      # Salesforce (Salesforce.com)
 'ULTA',     # Ulta Beauty, Inc.
 'VZ',       # Verizon Communications Inc.
 'WMT'       # Walmart Inc.
}

# %%
stock = "AAPL"
articles = get_articles(stock, "2025-07-09", "2025-08-09")
print(f"Fetched {len(articles)} articles.\n")
for art in articles[:5]:  # Show first 5
        print(f"{art['publishedAt']} - {art['title']}")
        print(art['content'])
        print(art['url'])
        print(art['author'])
        art['source']
# Out:
# Fetched 50 articles.
#
# 2025-07-21T03:59:48Z - Apple (AAPL) iPhone Production Soars as India Gains Prominence Amid Slowing U.S. Demand
# Apple Inc. (NASDAQ:AAPL) is one of the most profitable consumer stocks to buy now. Apple significantly ramped up iPhone production in the first half of 2025, with output rising 53% year-over-year to … [+2009 chars]
# https://finance.yahoo.com/news/apple-aapl-iphone-production-soars-035948543.html
# 2025-07-30T18:59:26Z - Apple Inc. (AAPL): Investor AI Worries Still Haven’t Pushed Stock To $190, Says Jim Cramer
# We recently published 10 Stocks On Jim Cramers Mind As He Discussed A Weird Number. Apple Inc. (NASDAQ:AAPL) is one of the stocks Jim Cramer recently discussed.
# Apple Inc. (NASDAQ:AAPL), the worlds … [+2225 chars]
# https://finance.yahoo.com/news/apple-inc-aapl-investor-ai-185926656.html
# 2025-07-25T11:45:48Z - JP Morgan will increase AAPL share target price -- eventually
# Investment analyst firm JP Morgan is predicting that Apple shares will improve in the short term, and predicts a target price rise by the end of 2026, through moderate iPhone 17 demand, but greater S… [+3011 chars]
# https://appleinsider.com/articles/25/07/25/jp-morgan-will-increase-aapl-share-target-price----eventually
# 2025-07-30T11:30:46Z - 'Magnificent Seven' stocks: Buy Nvidia, skip Apple
# The "Magnificent Seven," Nvidia (NVDA), Alphabet (GOOG, GOOGL), Tesla (TSLA), Microsoft (MSFT), Amazon (AMZN), Meta (META), and Apple (AAPL), have dominated the markets over the last couple of years.… [+303 chars]
# https://finance.yahoo.com/video/magnificent-seven-stocks-buy-nvidia-113046015.html
# 2025-07-30T13:26:48Z - AAPL Q3 2025: Analysts expect low growth, iPhone and Mac up, iPad down
# We’re just a day away from the AAPL Q3 2025 earnings report, covering April to June. Apple said it expected single-digit growth, and analysts expect this to be toward the lower end of the scale.
# Dig… [+2616 chars]
# https://9to5mac.com/2025/07/30/aapl-q3-2025-analysts-expect-low-growth-iphone-and-mac-up-ipad-down/

# %%
for stock in stocks:
    articles = get_articles(stock, "2025-07-09", "2025-08-09")
    print(f"Fetched {len(articles)} articles.\n")
# Out:
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 30 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 46 articles.
#
# Fetched 45 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 26 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 40 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 50 articles.
#
# Fetched 12 articles.
#
# Fetched 50 articles.
#
# Fetched 49 articles.
#
# Fetched 2 articles.
#
# Fetched 49 articles.
#
# Fetched 50 articles.
#
# Fetched 34 articles.
#
# Fetched 50 articles.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
