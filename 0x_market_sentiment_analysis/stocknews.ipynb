# %%
from stocknews import StockNews
import pandas as pd

# %%
API_KEY = "f89a5c3a5338bb662a04949d839e3697"

# %%
stocks = [
 'MMM',      # 3M
 'ATVI',     # Activision Blizzard
 'ADBE',     # Adobe
 'AES',      # AES Corporation
 'AMZN',     # Amazon.com
 'AMCR',     # Amcor plc
 'AMD',      # Advanced Micro Devices
 'AXP',      # American Express Company
 'AWK',      # American Water Works Company
 'AAPL',     # Apple Inc.
 'BBY',      # Best Buy Co., Inc.
 'SQ',       # Block, Inc. (formerly Square)
 'BA',       # Boeing
 'BXP',      # Boston Properties, Inc.
 'KO',       # Coca-Cola Company
 'GLW',      # Corning Inc.
 'COST',     # Costco Wholesale Corporation
 'CVS',      # CVS Health Corporation
 'EBAY',     # eBay Inc.
 'FDX',      # FedEx Corporation
 'FL',       # Foot Locker, Inc.
 'GIS',      # General Mills, Inc.
 'INTC',     # Intel Corporation
 'JNJ',      # Johnson & Johnson
 'JPM',      # JPMorgan Chase & Co.
 'KHC',      # Kraft Heinz Company
 'LMT',      # Lockheed Martin Corporation
 'MCD',      # McDonald’s Corporation
 'MGM',      # MGM Resorts International
 'MSFT',     # Microsoft Corporation
 'NFLX',     # Netflix, Inc.
 'NKE',      # Nike, Inc.
 'ORCL',     # Oracle Corporation
 'PYPL',     # PayPal Holdings, Inc.
 'PEP',      # PepsiCo, Inc.
 'PFE',      # Pfizer Inc.
 'PG',       # Procter & Gamble Co.
 'CRM',      # Salesforce (Salesforce.com)
 'ULTA',     # Ulta Beauty, Inc.
 'VZ',       # Verizon Communications Inc.
 'WMT'       # Walmart Inc.
]

# %%
#stocks = ['AAPL']
sn = StockNews(stocks, wt_key=API_KEY)
df = sn.summarize()

# %%
df_news = sn.read_rss()

# %%
df_news.sample(10)
# Out:
#                                      guid stock  \
# 468  f90ce7c7-f2e5-30e3-8e71-5cf1bac406e6   LMT
# 81   7b5005b9-b662-3a9e-9631-59cb95bebf23  AMZN
# 490  df50edfa-f72b-383c-8124-bbd1b0fbd358   MCD
# 612  bc24d53e-fe84-3838-8ce6-b5d5ec016bbd   PEP
# 13   0b01b7e2-5bb8-3b05-939a-b833a4cfa2e8  AAPL
# 202  1c172f38-d3a5-3f5b-a477-5b41f3d884ce    BA
# 24   ee28cb01-f96c-3862-81bd-a1ce95a67651   MMM
# 614  021ccd74-5aa9-379e-adeb-b82671c449df   PEP
# 641  2e3d4b69-7cc9-3a94-b21e-092f8830f52a    PG
# 442  989d2bee-4be7-3a39-9d89-173d137eecaf   KHC
#
#                                                  title  \
# 468  The Zacks Analyst Blog Highlights Rigetti Comp...
# 81                         Better Buy: Rivian vs. Ford
# 490  A Job Seeker With A Bachelor's Degree 'Got Lau...
# 612  Liberty Media Corporation Reports Second Quart...
# 13    Spending for Executive Protection Is on the Rise
# 202  Spirit AeroSystems Q2 revenues improved, but s...
# 24   3M's Safety & Industrial Revenues Accelerate: ...
# 614  Top Stock Reports for Morgan Stanley, PepsiCo ...
# 641  Baby Laundry Detergent Global Market Report 20...
# 442  Is Berkshire Hathaway Stock a Buy, Sell, or Ho...
#
#                                                summary  \
# 468  RGTI and QBTS show promise in quantum computin...
# 81   In the world of cars today, there's always a d...
# 490  A recent Reddit post is striking a nerve with ...
# 612  ENGLEWOOD, Colo., August 07, 2025--Liberty Med...
# 13   The median security expenditure for executives...
# 202  Agreements with major customers Boeing and Air...
# 24   MMM's Safety and Industrial unit posts fifth s...
# 614  MS rides strong trading gains and wealth focus...
# 641  The baby laundry detergent market is driven by...
# 442  No buybacks, a Kraft Heinz sting, and declinin...
#
#                            published           p_date  sentiment_summary  \
# 468  Wed, 06 Aug 2025 09:46:00 +0000   LMT_2025-08-06            -0.2846
# 81   Sat, 09 Aug 2025 22:05:00 +0000  AMZN_2025-08-09             0.0000
# 490  Thu, 07 Aug 2025 17:01:14 +0000   MCD_2025-08-07            -0.3400
# 612  Thu, 07 Aug 2025 12:15:00 +0000   PEP_2025-08-07             0.0000
# 13   Sat, 09 Aug 2025 00:02:00 +0000  AAPL_2025-08-09             0.3400
# 202  Fri, 08 Aug 2025 12:56:09 +0000    BA_2025-08-08             0.0516
# 24   Mon, 04 Aug 2025 14:47:00 +0000   MMM_2025-08-04             0.8225
# 614  Tue, 05 Aug 2025 19:29:00 +0000   PEP_2025-08-05             0.8126
# 641  Wed, 06 Aug 2025 08:20:00 +0000    PG_2025-08-06             0.5574
# 442  Thu, 07 Aug 2025 18:36:21 +0000   KHC_2025-08-07             0.5346
#
#      sentiment_title
# 468           0.0000
# 81            0.4404
# 490           0.6997
# 612           0.5267
# 13            0.0000
# 202          -0.1406
# 24            0.4215
# 614           0.2023
# 641           0.3182
# 442           0.0000

# %%
df_news.to_csv('news.csv')
